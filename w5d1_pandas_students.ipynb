# %% [markdown]
# # Week 5 Day 1 - Pandas
#
# [Pandas](https://pandas.pydata.org) is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. It is free software released under the three-clause BSD license.

# %%
import pandas as pd

# %%
# make a dictionary with lists as values
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# %%
#make it a dataframe

myCars = pd.DataFrame(mydataset)
myCars
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
#get the information of your dataframe

myCars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cars      3 non-null      object
#  1   passings  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
#get the shape of your dataframe

myCars.shape
# Out:
# (3, 2)

# %%
#get the columns

myCars.columns
# Out:
# Index(['cars', 'passings'], dtype='object')

# %%
#get the rows

myCars.values
# Out:
# array([['BMW', 3],
#        ['Volvo', 7],
#        ['Ford', 2]], dtype=object)

# %%
#get the axis

myCars.axes
# Out:
# [RangeIndex(start=0, stop=3, step=1),
#  Index(['cars', 'passings'], dtype='object')]

# %%
#get the first row
myCars.loc[0]
# Out:
# cars        BMW
# passings      3
# Name: 0, dtype: object

# %%
#use a list of indexs:

myCars.loc[[0,2]]
# Out:
#    cars  passings
# 0   BMW         3
# 2  Ford         2

# %%
#get a column

myCars['cars']
# Out:
# 0      BMW
# 1    Volvo
# 2     Ford
# Name: cars, dtype: object

# %%
#get the rows

myCars.loc[[0,1,2]]
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
#what are the datatypes of the dataframe

myCars.dtypes
# Out:
# cars        object
# passings     int64
# dtype: object

# %%
#change 'passings' to float
#set a new variable reference "passing" if you want change to carry

myCars['passings'].astype('float')
# Out:
# 0    3.0
# 1    7.0
# 2    2.0
# Name: passings, dtype: float64

# %%
#look at it again

myCars.dtypes
# Out:
# cars        object
# passings     int64
# dtype: object

# %%
#get rid of the last row
newDf = myCars.drop(2)

# %%
#get rid of the passings column

newDf2 = newDf.drop('passings',axis='columns')
newDf2
# Out:
#     cars
# 0    BMW
# 1  Volvo

# %% [markdown]
# <!--  -->

# %% [markdown]
# ### NaN & empty data

# %%
import numpy as np

uglyData = {
  'cars': ["BMW", 'Jeep', "Ford", 'Chrysler'],
  'passings': [3, np.nan, 2, 'NaN']
}

uglyDF = pd.DataFrame(uglyData)
uglyDF
# Out:
#        cars passings
# 0       BMW        3
# 1      Jeep      NaN
# 2      Ford        2
# 3  Chrysler      NaN

# %%
#drop the Nan

uglyDF_clean = uglyDF.dropna()
uglyDF_clean
# Out:
#        cars passings
# 0       BMW        3
# 2      Ford        2
# 3  Chrysler      NaN

# %%
#replace it with 0

uglyDF_clean2 = uglyDF.fillna(0)
uglyDF_clean2
# Out:
#        cars passings
# 0       BMW        3
# 1      Jeep        0
# 2      Ford        2
# 3  Chrysler      NaN

# %% [markdown]
# <!--  -->

# %% [markdown]
# ### .csv Files
#
# **pd.read_csv**
#
# A simple way to store big data sets is to use CSV files (comma separated files).
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
#
# *pd.read_csv(filepath_or_buffer, sep=’ ,’ , header=’infer’,  index_col=None, usecols=None, engine=None, skiprows=None, nrows=None)*

# %%
#import tv_shows.csv

df = pd.read_csv("tv_shows.csv")
df
# Out:
#       Unnamed: 0                         title              year   runtime  \
# 0              0               Game of Thrones  (2011 TV Series)  55 mins.
# 1              1                  Breaking Bad  (2008 TV Series)  45 mins.
# 2              2              The Walking Dead  (2010 TV Series)  44 mins.
# 3              3           The Big Bang Theory  (2007 TV Series)  22 mins.
# 4              4                        Dexter  (2006 TV Series)  55 mins.
# ...          ...                           ...               ...       ...
# 1969        1969                      Cristela  (2014 TV Series)  30 mins.
# 1970        1970        Power Rangers in Space  (1998 TV Series)  30 mins.
# 1971        1971               Reading Rainbow  (1983 TV Series)  30 mins.
# 1972        1972                   Martial Law  (1998 TV Series)  45 mins.
# 1973        1973  Beast Machines: Transformers  (1999 TV Series)  30 mins.
#
#       rating    votes                                            genre  \
# 0        9.5  748,557             [u'Adventure', u'Drama', u'Fantasy']
# 1        9.5  662,459                [u'Crime', u'Drama', u'Thriller']
# 2        8.7  500,301                            [u'Drama', u'Horror']
# 3        8.5  438,226                                      [u'Comedy']
# 4        8.9  419,031    [u'Crime', u'Drama', u'Mystery', u'Thriller']
# ...      ...      ...                                              ...
# 1969     6.3    1,510                                      [u'Comedy']
# 1970     7.2    1,504  [u'Action', u'Adventure', u'Family', u'Sci-Fi']
# 1971     8.5    1,501                                      [u'Family']
# 1972     7.1    1,501                 [u'Comedy', u'Crime', u'Action']
# 1973     6.9    1,500             [u'Action', u'Animation', u'Sci-Fi']
#
#                                                    text
# 0     Several noble families fight for control of th...
# 1     A chemistry teacher diagnosed with a terminal ...
# 2     Sheriff's Deputy Rick Grimes leads a group of ...
# 3     A woman who moves into an apartment across the...
# 4     A Miami police forensics expert moonlights as ...
# ...                                                 ...
# 1969  In her sixth year of law school, Cristela is f...
# 1970  The most evil forces of the universe (Rita &am...
# 1971  Levar Burton introduces young viewers to illus...
# 1972  A Shanghai cop who is a master of martial arts...
# 1973  The Maximals awaken on their home planet of Cy...
#
# [1974 rows x 8 columns]

# %%
#get a preview

# %%
#what columns of the csv file
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'runtime', 'rating', 'votes', 'genre',
#        'text'],
#       dtype='object')

# %%
# Return the number of not empty cells for each column/row

df2 = df.dropna()
df2.count()
# Out:
# Unnamed: 0    1792
# title         1792
# year          1792
# runtime       1792
# rating        1792
# votes         1792
# genre         1792
# text          1792
# dtype: int64

# %%
#only import the columns ["title", "year", "rating", "votes"]

df3 = pd.read_csv('tv_shows.csv', usecols=['title', 'year', 'rating', 'votes'])
df3.head()
# Out:
#                  title              year  rating    votes
# 0      Game of Thrones  (2011 TV Series)     9.5  748,557
# 1         Breaking Bad  (2008 TV Series)     9.5  662,459
# 2     The Walking Dead  (2010 TV Series)     8.7  500,301
# 3  The Big Bang Theory  (2007 TV Series)     8.5  438,226
# 4               Dexter  (2006 TV Series)     8.9  419,031

# %%
#what is the maximum rating? 

df3['rating'].max()
# Out:
# 9.6

# %%
#what is the minimum rating?
df3['rating'].min()
# Out:
# 1.8

# %%
#find the avg of all of the ratings

avgNum = df3['rating'].mean()
avgNum
# Out:
# 7.486524822695036

# %%
#what data types of the dataframe? 

df3.dtypes
# Out:
# title      object
# year       object
# rating    float64
# votes      object
# dtype: object

# %%
#can you change the datatype of votes?

df3['votes'] = df3.astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 #can you change the datatype of votes?
# ----> 3 df3['votes'] = df3.astype('float64')
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\dcdol\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Game of Thrones'

# %%
#set the index to be the names of the tv show
df4 = df3.set_index('title')
df4
# Out:
#                                           year  rating    votes
# title
# Game of Thrones               (2011 TV Series)     9.5  748,557
# Breaking Bad                  (2008 TV Series)     9.5  662,459
# The Walking Dead              (2010 TV Series)     8.7  500,301
# The Big Bang Theory           (2007 TV Series)     8.5  438,226
# Dexter                        (2006 TV Series)     8.9  419,031
# ...                                        ...     ...      ...
# Cristela                      (2014 TV Series)     6.3    1,510
# Power Rangers in Space        (1998 TV Series)     7.2    1,504
# Reading Rainbow               (1983 TV Series)     8.5    1,501
# Martial Law                   (1998 TV Series)     7.1    1,501
# Beast Machines: Transformers  (1999 TV Series)     6.9    1,500
#
# [1974 rows x 3 columns]

# %%
#get the year of hte new dataframe

# %% [markdown]
# <!--  -->

# %% [markdown]
# ### .json files
#
# **pd.read_json**
#
# JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries. If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly.

# %%
dataJson = {
    'item1':{
        "0":60,
        "1":60,
        "2":60
    },
    'item2':{
        '0':100,
        '1':100,
        '2':100
    }
}

# %%
dfjason = pd.DataFrame(dataJson)  
dfjason
# Out:
#    item1  item2
# 0     60    100
# 1     60    100
# 2     60    100

# %%
#read in nationalParks.json

df = pd.read_json('nationalParks.json')
df.head()
# Out:
#                                               area  \
# 0     {'acres': '49,057.36', 'square_km': '198.5'}
# 1       {'acres': '8,256.67', 'square_km': '33.4'}
# 2     {'acres': '76,678.98', 'square_km': '310.3'}
# 3    {'acres': '242,755.94', 'square_km': '982.4'}
# 4  {'acres': '801,163.21', 'square_km': '3,242.2'}
#
#                                   coordinates date_established_readable  \
# 0    {'latitude': 44.35, 'longitude': -68.21}         February 26, 1919
# 1  {'latitude': -14.25, 'longitude': -170.68}          October 31, 1988
# 2   {'latitude': 38.68, 'longitude': -109.57}         November 12, 1971
# 3    {'latitude': 43.75, 'longitude': -102.5}         November 10, 1978
# 4   {'latitude': 29.25, 'longitude': -103.25}             June 12, 1944
#
#    date_established_unix                                        description  \
# 0            -1604599200  Covering most of Mount Desert Island and other...
# 1              594280800  The southernmost National Park is on three Sam...
# 2               58773600  This site features more than 2,000 natural san...
# 3              279525600  The Badlands are a collection of buttes, pinna...
# 4             -806439600  Named for the prominent bend in the Rio Grande...
#
#                                                image  \
# 0  {'url': 'acadia.jpg', 'attribution': 'PixelBay...
# 1  {'url': 'american-samoa.jpg', 'attribution': '...
# 2  {'url': 'arches.jpg', 'attribution': 'PixelBay...
# 3  {'url': 'badlands.jpg', 'attribution': 'PixelB...
# 4  {'url': 'big-bend.jpg', 'attribution': 'PixelB...
#
#                              nps_link  \
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/npsa/index.htm
# 2  https://www.nps.gov/arch/index.htm
# 3  https://www.nps.gov/badl/index.htm
# 4  https://www.nps.gov/bibe/index.htm
#
#                                               states           title  \
# 0          [{'id': 'state_maine', 'title': 'Maine'}]          Acadia
# 1  [{'id': 'state_american-samoa', 'title': 'Amer...  American Samoa
# 2            [{'id': 'state_utah', 'title': 'Utah'}]          Arches
# 3  [{'id': 'state_south-dakota', 'title': 'South ...        Badlands
# 4          [{'id': 'state_texas', 'title': 'Texas'}]        Big Bend
#
#                     id   visitors  world_heritage_site
# 0          park_acadia  3,303,393                False
# 1  park_american-samoa     28,892                False
# 2          park_arches  1,585,718                False
# 3        park_badlands    996,263                False
# 4        park_big-bend    388,290                False

# %%
df.dtypes
# Out:
# area                         object
# coordinates                  object
# date_established_readable    object
# date_established_unix         int64
# description                  object
# image                        object
# nps_link                     object
# states                       object
# title                        object
# id                           object
# visitors                     object
# world_heritage_site            bool
# dtype: object

# %%
#only get the ['date_established_readable','description', 'title', 'visitors', 'world_heritage_site', 'states ]

df2 = df[['title','visitors','date_established_readable', 'description', 'title', 'world_heritage_site', 'states']]
df2.head()
# Out:
#             title   visitors date_established_readable  \
# 0          Acadia  3,303,393         February 26, 1919
# 1  American Samoa     28,892          October 31, 1988
# 2          Arches  1,585,718         November 12, 1971
# 3        Badlands    996,263         November 10, 1978
# 4        Big Bend    388,290             June 12, 1944
#
#                                          description           title  \
# 0  Covering most of Mount Desert Island and other...          Acadia
# 1  The southernmost National Park is on three Sam...  American Samoa
# 2  This site features more than 2,000 natural san...          Arches
# 3  The Badlands are a collection of buttes, pinna...        Badlands
# 4  Named for the prominent bend in the Rio Grande...        Big Bend
#
#    world_heritage_site                                             states
# 0                False          [{'id': 'state_maine', 'title': 'Maine'}]
# 1                False  [{'id': 'state_american-samoa', 'title': 'Amer...
# 2                False            [{'id': 'state_utah', 'title': 'Utah'}]
# 3                False  [{'id': 'state_south-dakota', 'title': 'South ...
# 4                False          [{'id': 'state_texas', 'title': 'Texas'}]

# %%
#get the datatypes

df2.dtypes
# Out:
# title                        object
# visitors                     object
# date_established_readable    object
# description                  object
# title                        object
# world_heritage_site            bool
# states                       object
# dtype: object

# %%
#find the national parks that are world heritage sites

whsNum = df2[df2['world_heritage_site']== True]
len(whsNum)
# Out:
# 14

# %% [markdown]
# <!--  -->

# %% [markdown]
# #### Exercise 1: get the national parks with over a million visitors

# %%
df2_cleanVis = df2

df2_cleanVis['visitors'] = df2_cleanVis['visitors'].replace(',','',regex=True)
df2_cleanVis.head()
# Out:
# C:\Users\dcdol\AppData\Local\Temp\ipykernel_16164\2724749226.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleanVis['visitors'] = df2_cleanVis['visitors'].replace(',','',regex=True)
#             title visitors date_established_readable  \
# 0          Acadia  3303393         February 26, 1919
# 1  American Samoa    28892          October 31, 1988
# 2          Arches  1585718         November 12, 1971
# 3        Badlands   996263         November 10, 1978
# 4        Big Bend   388290             June 12, 1944
#
#                                          description           title  \
# 0  Covering most of Mount Desert Island and other...          Acadia
# 1  The southernmost National Park is on three Sam...  American Samoa
# 2  This site features more than 2,000 natural san...          Arches
# 3  The Badlands are a collection of buttes, pinna...        Badlands
# 4  Named for the prominent bend in the Rio Grande...        Big Bend
#
#    world_heritage_site                                             states
# 0                False          [{'id': 'state_maine', 'title': 'Maine'}]
# 1                False  [{'id': 'state_american-samoa', 'title': 'Amer...
# 2                False            [{'id': 'state_utah', 'title': 'Utah'}]
# 3                False  [{'id': 'state_south-dakota', 'title': 'South ...
# 4                False          [{'id': 'state_texas', 'title': 'Texas'}]

# %%
df2_cleanVis['visitors'] = df2_cleanVis['visitors'].astype('int64')
df2_cleanVis = df2_cleanVis[df2_cleanVis['visitors']>1000000]

df2_cleanVis
# Out:
# C:\Users\dcdol\AppData\Local\Temp\ipykernel_16164\3697110578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleanVis['visitors'] = df2_cleanVis['visitors'].astype('int64')
#                     title  visitors date_established_readable  \
# 0                  Acadia   3303393         February 26, 1919
# 2                  Arches   1585718         November 12, 1971
# 7            Bryce Canyon   2365110         February 25, 1928
# 9            Capitol Reef   1064904         December 18, 1971
# 14        Cuyahoga Valley   2423390          October 11, 2000
# 15           Death Valley   1296283          October 31, 1994
# 20                Glacier   2946681              May 11, 1910
# 22           Grand Canyon   5969811         February 26, 1919
# 23            Grand Teton   3270076         February 26, 1929
# 26  Great Smoky Mountains  11312786             June 15, 1934
# 28              Haleakala   1263558            August 1, 1916
# 29       Hawaii Volcanoes   1887580            August 1, 1916
# 30            Hot Springs   1544300             March 4, 1921
# 32            Joshua Tree   2505286          October 31, 1994
# 41          Mount Rainier   1356913             March 2, 1899
# 43                Olympic   3390221             June 29, 1938
# 47         Rocky Mountain   4517585          January 26, 1915
# 49                Sequoia   1254688        September 25, 1890
# 50             Shenandoah   1437341         December 26, 1935
# 56            Yellowstone   4257177             March 1, 1872
# 57               Yosemite   5028868           October 1, 1890
# 58                   Zion   4295127         November 19, 1919
#
#                                           description                  title  \
# 0   Covering most of Mount Desert Island and other...                 Acadia
# 2   This site features more than 2,000 natural san...                 Arches
# 7   Bryce Canyon is a geological amphitheater on t...           Bryce Canyon
# 9   The park's Waterpocket Fold is a 100-mile (160...           Capitol Reef
# 14  This park along the Cuyahoga River has waterfa...        Cuyahoga Valley
# 15  Death Valley is the hottest, lowest, and dries...           Death Valley
# 20  The U.S. half of Waterton-Glacier Internationa...                Glacier
# 22  The Grand Canyon, carved by the mighty Colorad...           Grand Canyon
# 23  Grand Teton is the tallest mountain in the Tet...            Grand Teton
# 26  The Great Smoky Mountains, part of the Appalac...  Great Smoky Mountains
# 28  The Haleakala volcano on Maui features a very ...              Haleakala
# 29  This park on the Big Island protects the Kīlau...       Hawaii Volcanoes
# 30  Hot Springs was established by act of Congress...            Hot Springs
# 32  Covering large areas of the Colorado and Mojav...            Joshua Tree
# 41  Mount Rainier, an active stratovolcano, is the...          Mount Rainier
# 43  Situated on the Olympic Peninsula, this park i...                Olympic
# 47  Bisected north to south by the Continental Div...         Rocky Mountain
# 49  This park protects the Giant Forest, which boa...                Sequoia
# 50  Shenandoah's Blue Ridge Mountains are covered ...             Shenandoah
# 56  Situated on the Yellowstone Caldera, the park ...            Yellowstone
# 57  Yosemite features sheer granite cliffs, except...               Yosemite
# 58  Located at the junction of the Colorado Platea...                   Zion
#
#     world_heritage_site                                             states
# 0                 False          [{'id': 'state_maine', 'title': 'Maine'}]
# 2                 False            [{'id': 'state_utah', 'title': 'Utah'}]
# 7                 False            [{'id': 'state_utah', 'title': 'Utah'}]
# 9                 False            [{'id': 'state_utah', 'title': 'Utah'}]
# 14                False            [{'id': 'state_ohio', 'title': 'Ohio'}]
# 15                False  [{'id': 'state_california', 'title': 'Californ...
# 20                 True      [{'id': 'state_montana', 'title': 'Montana'}]
# 22                 True      [{'id': 'state_arizona', 'title': 'Arizona'}]
# 23                False      [{'id': 'state_wyoming', 'title': 'Wyoming'}]
# 26                 True  [{'id': 'state_tennessee', 'title': 'Tennessee...
# 28                False        [{'id': 'state_hawaii', 'title': 'Hawaii'}]
# 29                 True        [{'id': 'state_hawaii', 'title': 'Hawaii'}]
# 30                False    [{'id': 'state_arkansas', 'title': 'Arkansas'}]
# 32                False  [{'id': 'state_california', 'title': 'Californ...
# 41                False  [{'id': 'state_washington', 'title': 'Washingt...
# 43                 True  [{'id': 'state_washington', 'title': 'Washingt...
# 47                False    [{'id': 'state_colorado', 'title': 'Colorado'}]
# 49                False  [{'id': 'state_california', 'title': 'Californ...
# 50                False    [{'id': 'state_virginia', 'title': 'Virginia'}]
# 56                 True  [{'id': 'state_wyoming', 'title': 'Wyoming'}, ...
# 57                 True  [{'id': 'state_california', 'title': 'Californ...
# 58                False            [{'id': 'state_utah', 'title': 'Utah'}]

# %% [markdown]
# <!--  -->

# %% [markdown]
# ### Exercise 2: Create a dictionary of the number of national parks per state

# %%
df2['states']
df2
# Out:
#                            title  visitors date_established_readable  \
# 0                         Acadia   3303393         February 26, 1919
# 1                 American Samoa     28892          October 31, 1988
# 2                         Arches   1585718         November 12, 1971
# 3                       Badlands    996263         November 10, 1978
# 4                       Big Bend    388290             June 12, 1944
# 5                       Biscayne    514709             June 28, 1980
# 6   Black Canyon of the Gunnison    238018          October 21, 1999
# 7                   Bryce Canyon   2365110         February 25, 1928
# 8                    Canyonlands    776218        September 12, 1964
# 9                   Capitol Reef   1064904         December 18, 1971
# 10              Carlsbad Caverns    466773              May 14, 1930
# 11               Channel Islands    364807             March 5, 1980
# 12                      Congaree    143843         November 10, 2003
# 13                   Crater Lake    756344              May 22, 1902
# 14               Cuyahoga Valley   2423390          October 11, 2000
# 15                  Death Valley   1296283          October 31, 1994
# 16                        Denali    587412         February 26, 1917
# 17                  Dry Tortugas     73661          October 26, 1992
# 18                    Everglades    930907              May 30, 1934
# 19           Gates of the Arctic     10047          December 2, 1980
# 20                       Glacier   2946681              May 11, 1910
# 21                   Glacier Bay    520171          December 2, 1980
# 22                  Grand Canyon   5969811         February 26, 1919
# 23                   Grand Teton   3270076         February 26, 1929
# 24                   Great Basin    144846          October 27, 1986
# 25              Great Sand Dunes    388308        September 13, 2004
# 26         Great Smoky Mountains  11312786             June 15, 1934
# 27           Guadalupe Mountains    181839          October 15, 1966
# 28                     Haleakala   1263558            August 1, 1916
# 29              Hawaii Volcanoes   1887580            August 1, 1916
# 30                   Hot Springs   1544300             March 4, 1921
# 31                   Isle Royale     24966             April 3, 1940
# 32                   Joshua Tree   2505286          October 31, 1994
# 33                        Katmai     37818          December 2, 1980
# 34                  Kenai Fjords    346534          December 2, 1980
# 35                  Kings Canyon    607479             March 4, 1940
# 36                  Kobuk Valley     15500          December 2, 1980
# 37                    Lake Clark     21102          December 2, 1980
# 38               Lassen Volcanic    536068            August 9, 1916
# 39                  Mammoth Cave    586514              July 1, 1941
# 40                    Mesa Verde    583527             June 29, 1906
# 41                 Mount Rainier   1356913             March 2, 1899
# 42                North Cascades     28646           October 2, 1968
# 43                       Olympic   3390221             June 29, 1938
# 44              Petrified Forest    643274          December 9, 1962
# 45                     Pinnacles    215555          January 10, 2013
# 46                       Redwood    536297           October 2, 1968
# 47                Rocky Mountain   4517585          January 26, 1915
# 48                       Saguaro    820426          October 14, 1994
# 49                       Sequoia   1254688        September 25, 1890
# 50                    Shenandoah   1437341         December 26, 1935
# 51            Theodore Roosevelt    753880         November 10, 1978
# 52                Virgin Islands    411343            August 2, 1956
# 53                     Voyageurs    241912           January 8, 1971
# 54                     Wind Cave    617377           January 9, 1903
# 55            Wrangell–St. Elias     79047          December 2, 1980
# 56                   Yellowstone   4257177             March 1, 1872
# 57                      Yosemite   5028868           October 1, 1890
# 58                          Zion   4295127         November 19, 1919
#
#                                           description  \
# 0   Covering most of Mount Desert Island and other...
# 1   The southernmost National Park is on three Sam...
# 2   This site features more than 2,000 natural san...
# 3   The Badlands are a collection of buttes, pinna...
# 4   Named for the prominent bend in the Rio Grande...
# 5   Located in Biscayne Bay, this park at the nort...
# 6   The park protects a quarter of the Gunnison Ri...
# 7   Bryce Canyon is a geological amphitheater on t...
# 8   This landscape was eroded into a maze of canyo...
# 9   The park's Waterpocket Fold is a 100-mile (160...
# 10  Carlsbad Caverns has 117 caves, the longest of...
# 11  Five of the eight Channel Islands are protecte...
# 12  On the Congaree River, this park is the larges...
# 13  Crater Lake lies in the caldera of an ancient ...
# 14  This park along the Cuyahoga River has waterfa...
# 15  Death Valley is the hottest, lowest, and dries...
# 16  Centered on Denali, the tallest mountain in No...
# 17  The islands of the Dry Tortugas, at the wester...
# 18  The Everglades are the largest tropical wilder...
# 19  The country's northernmost park protects an ex...
# 20  The U.S. half of Waterton-Glacier Internationa...
# 21  Glacier Bay contains tidewater glaciers, mount...
# 22  The Grand Canyon, carved by the mighty Colorad...
# 23  Grand Teton is the tallest mountain in the Tet...
# 24  Based around Nevada's second tallest mountain,...
# 25  The tallest sand dunes in North America, up to...
# 26  The Great Smoky Mountains, part of the Appalac...
# 27  This park contains Guadalupe Peak, the highest...
# 28  The Haleakala volcano on Maui features a very ...
# 29  This park on the Big Island protects the Kīlau...
# 30  Hot Springs was established by act of Congress...
# 31  The largest island in Lake Superior is a place...
# 32  Covering large areas of the Colorado and Mojav...
# 33  This park on the Alaska Peninsula protects the...
# 34  Near Seward on the Kenai Peninsula, this park ...
# 35  Home to several giant sequoia groves and the G...
# 36  Kobuk Valley protects 61 miles (98 km) of the ...
# 37  The region around Lake Clark features four act...
# 38  Lassen Peak, the largest plug dome volcano in ...
# 39  With more than 400 miles (640 km) of passagewa...
# 40  This area constitutes over 4,000 archaeologica...
# 41  Mount Rainier, an active stratovolcano, is the...
# 42  This complex encompasses two units of the Nati...
# 43  Situated on the Olympic Peninsula, this park i...
# 44  This portion of the Chinle Formation has a lar...
# 45  Named for the eroded leftovers of a portion of...
# 46  This park and the co-managed state parks prote...
# 47  Bisected north to south by the Continental Div...
# 48  Split into the separate Rincon Mountain and Tu...
# 49  This park protects the Giant Forest, which boa...
# 50  Shenandoah's Blue Ridge Mountains are covered ...
# 51  This region that enticed and influenced Presid...
# 52  This island park on Saint John preserves Taíno...
# 53  This park protecting four lakes near the Canad...
# 54  Wind Cave is distinctive for its calcite fin f...
# 55  An over 8 million acres (32,375 km2) plot of m...
# 56  Situated on the Yellowstone Caldera, the park ...
# 57  Yosemite features sheer granite cliffs, except...
# 58  Located at the junction of the Colorado Platea...
#
#                            title  world_heritage_site  \
# 0                         Acadia                False
# 1                 American Samoa                False
# 2                         Arches                False
# 3                       Badlands                False
# 4                       Big Bend                False
# 5                       Biscayne                False
# 6   Black Canyon of the Gunnison                False
# 7                   Bryce Canyon                False
# 8                    Canyonlands                False
# 9                   Capitol Reef                False
# 10              Carlsbad Caverns                 True
# 11               Channel Islands                False
# 12                      Congaree                False
# 13                   Crater Lake                False
# 14               Cuyahoga Valley                False
# 15                  Death Valley                False
# 16                        Denali                False
# 17                  Dry Tortugas                False
# 18                    Everglades                 True
# 19           Gates of the Arctic                False
# 20                       Glacier                 True
# 21                   Glacier Bay                 True
# 22                  Grand Canyon                 True
# 23                   Grand Teton                False
# 24                   Great Basin                False
# 25              Great Sand Dunes                False
# 26         Great Smoky Mountains                 True
# 27           Guadalupe Mountains                False
# 28                     Haleakala                False
# 29              Hawaii Volcanoes                 True
# 30                   Hot Springs                False
# 31                   Isle Royale                False
# 32                   Joshua Tree                False
# 33                        Katmai                False
# 34                  Kenai Fjords                False
# 35                  Kings Canyon                False
# 36                  Kobuk Valley                False
# 37                    Lake Clark                False
# 38               Lassen Volcanic                False
# 39                  Mammoth Cave                 True
# 40                    Mesa Verde                 True
# 41                 Mount Rainier                False
# 42                North Cascades                False
# 43                       Olympic                 True
# 44              Petrified Forest                False
# 45                     Pinnacles                False
# 46                       Redwood                 True
# 47                Rocky Mountain                False
# 48                       Saguaro                False
# 49                       Sequoia                False
# 50                    Shenandoah                False
# 51            Theodore Roosevelt                False
# 52                Virgin Islands                False
# 53                     Voyageurs                False
# 54                     Wind Cave                False
# 55            Wrangell–St. Elias                 True
# 56                   Yellowstone                 True
# 57                      Yosemite                 True
# 58                          Zion                False
#
#                                                states
# 0           [{'id': 'state_maine', 'title': 'Maine'}]
# 1   [{'id': 'state_american-samoa', 'title': 'Amer...
# 2             [{'id': 'state_utah', 'title': 'Utah'}]
# 3   [{'id': 'state_south-dakota', 'title': 'South ...
# 4           [{'id': 'state_texas', 'title': 'Texas'}]
# 5       [{'id': 'state_florida', 'title': 'Florida'}]
# 6     [{'id': 'state_colorado', 'title': 'Colorado'}]
# 7             [{'id': 'state_utah', 'title': 'Utah'}]
# 8             [{'id': 'state_utah', 'title': 'Utah'}]
# 9             [{'id': 'state_utah', 'title': 'Utah'}]
# 10  [{'id': 'state_new-mexico', 'title': 'New Mexi...
# 11  [{'id': 'state_california', 'title': 'Californ...
# 12  [{'id': 'state_south-carolina', 'title': 'Sout...
# 13        [{'id': 'state_oregon', 'title': 'Oregon'}]
# 14            [{'id': 'state_ohio', 'title': 'Ohio'}]
# 15  [{'id': 'state_california', 'title': 'Californ...
# 16        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 17      [{'id': 'state_florida', 'title': 'Florida'}]
# 18      [{'id': 'state_florida', 'title': 'Florida'}]
# 19        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 20      [{'id': 'state_montana', 'title': 'Montana'}]
# 21        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 22      [{'id': 'state_arizona', 'title': 'Arizona'}]
# 23      [{'id': 'state_wyoming', 'title': 'Wyoming'}]
# 24        [{'id': 'state_nevada', 'title': 'Nevada'}]
# 25    [{'id': 'state_colorado', 'title': 'Colorado'}]
# 26  [{'id': 'state_tennessee', 'title': 'Tennessee...
# 27          [{'id': 'state_texas', 'title': 'Texas'}]
# 28        [{'id': 'state_hawaii', 'title': 'Hawaii'}]
# 29        [{'id': 'state_hawaii', 'title': 'Hawaii'}]
# 30    [{'id': 'state_arkansas', 'title': 'Arkansas'}]
# 31    [{'id': 'state_michigan', 'title': 'Michigan'}]
# 32  [{'id': 'state_california', 'title': 'Californ...
# 33        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 34        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 35  [{'id': 'state_california', 'title': 'Californ...
# 36        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 37        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 38  [{'id': 'state_california', 'title': 'Californ...
# 39    [{'id': 'state_kentucky', 'title': 'Kentucky'}]
# 40    [{'id': 'state_colorado', 'title': 'Colorado'}]
# 41  [{'id': 'state_washington', 'title': 'Washingt...
# 42  [{'id': 'state_washington', 'title': 'Washingt...
# 43  [{'id': 'state_washington', 'title': 'Washingt...
# 44      [{'id': 'state_arizona', 'title': 'Arizona'}]
# 45  [{'id': 'state_california', 'title': 'Californ...
# 46  [{'id': 'state_california', 'title': 'Californ...
# 47    [{'id': 'state_colorado', 'title': 'Colorado'}]
# 48      [{'id': 'state_arizona', 'title': 'Arizona'}]
# 49  [{'id': 'state_california', 'title': 'Californ...
# 50    [{'id': 'state_virginia', 'title': 'Virginia'}]
# 51  [{'id': 'state_north-dakota', 'title': 'North ...
# 52  [{'id': 'state_us-virgin-islands', 'title': 'U...
# 53  [{'id': 'state_minnesota', 'title': 'Minnesota'}]
# 54  [{'id': 'state_south-dakota', 'title': 'South ...
# 55        [{'id': 'state_alaska', 'title': 'Alaska'}]
# 56  [{'id': 'state_wyoming', 'title': 'Wyoming'}, ...
# 57  [{'id': 'state_california', 'title': 'Californ...
# 58            [{'id': 'state_utah', 'title': 'Utah'}]
